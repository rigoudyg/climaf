# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.misc import imread
import matplotlib.cbook as cbook
from IPython.display import Image

# %%
datafile = '/home/jservon/Evaluation/CliMAF/FreshWaterBudget-HadGEM2.png'
img = imread(datafile)

# %%
fig = plt.figure()
plt.imshow(img, zorder=0, extent=[0, 30, 0, 20])
fig.suptitle('Fresh Water Budget ${Model} ${simulation} ${period}', fontsize=14, fontweight='bold')
ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)

# -- ATMOSPHERE
ATMOSPHERE_x = 13.3
ATMOSPHERE_y = 16.6
ATMOSPHERE_val = str(-0.002)
ax.text(ATMOSPHERE_x, ATMOSPHERE_y, ATMOSPHERE_val, 
        bbox={'facecolor':'white', 'pad':2})

# -- OCEAN
OCEAN_x = 17.5
OCEAN_y = 3.3
OCEAN_val = str(-0.002)
ax.text(OCEAN_x, OCEAN_y, OCEAN_val, 
        bbox={'facecolor':'white', 'pad':2})

# -- SEA ICE
SEAICE_x = 23.5
SEAICE_y = 8.8
SEAICE_val = str(-0.002)
ax.text(SEAICE_x, SEAICE_y, SEAICE_val, fontsize=10,
        bbox={'facecolor':'white', 'pad':2})

# -- SNOW
SNOW_x = 5.6
SNOW_y = 12.3
SNOW_val = str(-0.002)
ax.text(SNOW_x, SNOW_y, SNOW_val, fontsize=10,
        bbox={'facecolor':'white', 'pad':2})

# -- ICE SHEETS
ICESHEETS_x = 11.9
ICESHEETS_y = 12.3
ICESHEETS_val = str(-0.002)
ax.text(ICESHEETS_x, ICESHEETS_y, ICESHEETS_val, fontsize=10,
        bbox={'facecolor':'white', 'pad':2})

# -- SOIL MOISTURE
SOILMOISTURE_x = 3.8
SOILMOISTURE_y = 7.8
SOILMOISTURE_val = str(-0.002)
ax.text(SOILMOISTURE_x, SOILMOISTURE_y, SOILMOISTURE_val, fontsize=10,
        bbox={'facecolor':'white', 'pad':2})

# -- RIVERS
RIVERS_x = 3.8
RIVERS_y = 3.7
RIVERS_val = str(-0.002)
ax.text(RIVERS_x, RIVERS_y, RIVERS_val, fontsize=10,
        bbox={'facecolor':'white', 'pad':2})

ax.axis([0, 30, 0, 20])

fig.savefig('test.png')
Image(filename='test.png')
