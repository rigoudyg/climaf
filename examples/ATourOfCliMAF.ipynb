# %% [markdown]
# # CliMAF tour

# %% [markdown]
# # CliMAF is a framework for Climate Model Assessment. It allows to combine diagnostic binaries, scripts and Python functions as easily as possible

# %% [markdown]
# ## Here  : defining a dataset and its location, defining and using operators based on external scripts/binaries or Python functions, assembling all, illustrating cache features, plotting and 'exporting' results (as files or MaskedArrays)

# %% [markdown]
# ### Init CliMAF

# %%
from climaf.api import *
# Out:
# Climaf_version=0.5

# %% [markdown]
# ### For the sake of the demo , tell CliMAF to be a bit verbose (both on stderr and on logging file), and erase any previous result

# %%
clog('info')
clog_file('debug')
craz()

# %% [markdown]
# # 1- Data location and datasets

# %% [markdown]
# ### Declare data organization a given 'project' (usually done in config files)

# %%
dataloc(project="example",organization="generic",url=[\
        cpath+"/../examples/data/${experiment}/L/${experiment}SFXYYYY.nc", \
        cpath+"/../examples/data/${experiment}/A/${experiment}PLYYYY.nc"])
# Out:
# <climaf.dataloc.dataloc instance at 0x7fc1d4549368>

# %% [markdown]
# ### Define a default value for some dataset facets

# %%
cdef("project","example")
cdef("period","1980-1981")

# %% [markdown]
# ### Define a dataset based on the experiment defined above (this uses the facets default values)

# %%
tas_ds=ds(experiment="AMIPV6ALB2G", variable="tas")

# %% [markdown]
# ### You can also define a dataset restricted to a latlon box

# %%
tas_ds_r=ds(experiment="AMIPV6ALB2G", variable="tas", domain=[10,80,-50,40])

# %% [markdown]
# ### Have a look at dataset's symbolic expression (other patterns could apply , according to project's "DRS")

# %%
tas_ds_r
# Out:
# ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly')

# %% [markdown]
# # 2- CliMAF manages the access to the data for a number of organizations

# %% [markdown]
# ### CliMAF can identify all the files relevant to the dataset (see CMIP5 DRS case further below, § 12)

# %%
tas_ds.baseFiles()
# Out:
# '/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc'

# %% [markdown]
# ### It can also hande other organizations : CMIP5 DRS, EM, OBS4MIPs at CNRM, OCMIP5 on IPSL's Ciclad, CAMI obs at CNRM

# %% [markdown]
# # 4- Using external scripts and binaries for implementing diagnostics

# %% [markdown]
# ### First diagnostic is basic climatology - Let us declare a 'CliMAF operator' for this diag, using an external script and some keywords conventions

# %%
cscript('time_average' ,cpath+'/../scripts/time_average_basics.sh ${out} ${in}' )
# Out:
# [__init__   : operators.py, L. 186 ] : WARNING  : Redefining CliMAF script time_average
# CliMAF operator : time_average

# %% [markdown]
# ### Let us have a look at the script involved : this one is pure bash wrapping around CDO calls

# %%
# %load ../scripts/time_average_basics.sh

# %%
#!/bin/bash
# Applies the timavg cdo operator to a list of FILES 
# and applies ncwa for discarding degenerated singleton time dimension
# Puts results in OUT 
# Exit with non-0 status if any problem

set -ex 
out=$1
files=$2

tmp3=$(mktemp /tmp/tmp_file.XXXXXX) 

cdo timavg $files $out
ncwa -O -a time $out $tmp3 && ncks -O -x -v time $tmp3 $out && rm $tmp3
# Out:
#   File "<ipython-input-12-0e0fbd5ec259>", line 8
#     out=$1
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Declaring a 'CliMAF operator' actually creates a Python function

# %%
time_average
# Out:
# <function __main__.time_average>

# %% [markdown]
# ### A doc string is available for each 'operator function' (the same as for on-line doc)

# %%
help(time_average)
# Out:
# Help on function time_average in module __main__:
#
# time_average(*args, **dic)
#     time_average : compute time average for all time steps
#     -------------------------------------------------------
#
#     Apply operator timavg on the object/dataset to another grid, using CDO
#
#     **References** : https://code.zmaw.de/projects/cdo/embedded/1.6.4/cdo.html#x1-3560002.8.14
#
#     **Provider / contact** : climaf at meteo dot fr
#
#     **Inputs** (in the order of CliMAF call):
#       - any dataset (but only one)
#
#     **Mandatory arguments**: none
#
#     **Optional arguments**: none
#
#     **Output** : the time-averaged object
#
#     **Climaf call example** ::
#
#       >>> ds= .... #some dataset, with whatever variable
#       >>> ds_tavg=time_average(ds)
#
#     **Side effects** : None
#
#     **Implementation** : CDO call with operator ``timavg``,  through script mcdo.sh

# %% [markdown]
# ### Symbolically apply the script to a dataset, using the 'CliMAF operator', and have a look at object/symbol result

# %%
tas_avg=time_average(tas_ds)
tas_avg
# Out:
# time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'))

# %% [markdown]
# # 5- From CliMAF objects to files or Masked Array

# %% [markdown]
# ### Computation actually occurs when wanting to 'export' objects in some way : here as a file using 'cfile'

# %%
cfile(tas_avg)
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'))
# 			[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for select(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'))
# 			[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh "" /home/senesi/tmp/climaf_cache/da/c.nc "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc"
# 			[register   : cache.py  , L. 124 ] : INFO     : select(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) registered as /home/senesi/tmp/climaf_cache/da/c.nc
# 			[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 1 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh "" /home/senesi/tmp/climaf_cache/da/c.nc "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc"
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/time_average_basics.sh /home/senesi/tmp/climaf_cache/86/4.nc "/home/senesi/tmp/climaf_cache/da/c.nc"
# 	[register   : cache.py  , L. 124 ] : INFO     : time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) registered as /home/senesi/tmp/climaf_cache/86/4.nc
# 	[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 0.8 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/time_average_basics.sh /home/senesi/tmp/climaf_cache/86/4.nc "/home/senesi/tmp/climaf_cache/da/c.nc"
# '/home/senesi/tmp/climaf_cache/86/4.nc'

# %% [markdown]
# ### The file cache will be used whenever the same object is requested (or even for an included objet). Here, in addition, we request a copy of the cache file, at some location

# %%
cfile(tas_ds,"~/tmp/tasavg.nc")
# Out:
# 		[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: select(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/senesi/tmp/climaf_cache/da/c.nc:
# '~/tmp/tasavg.nc'

# %% [markdown]
# ### Another export format : MaskedArrays (others could apply, as e.g. CDAT's MV)

# %%
tas_avg_MA=cMA(tas_avg)
# Out:
# 	[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/senesi/tmp/climaf_cache/86/4.nc:

# %% [markdown]
# ### Looking at the result

# %%
type(tas_avg_MA)
# Out:
# numpy.ma.core.MaskedArray

# %%
tas_avg_MA.shape
# Out:
# (128, 256)

# %% [markdown]
# # 6- Display a simple figure

# %% [markdown]
# ### Plot the data, first way : let us declare a 'CliMAF operator', for using binary 'ncview', and with output format == None

# %%
cscript('my_ncview' ,'ncview ${in}' , format=None)
# Out:
# CliMAF operator : my_ncview

# %% [markdown]
# ### As a special case, apply such an operator also launches the computation, which here means to display [ Nothing will show on web-only demo ]

# %%
vfig=my_ncview(tas_avg)
vfig
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for my_ncview(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')))
# 		[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/senesi/tmp/climaf_cache/86/4.nc:
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:ncview "/home/senesi/tmp/climaf_cache/86/4.nc"
# my_ncview(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')))

# %% [markdown]
# ### The vfig 'object' can also be shown again using cshow  [ Again - Nothing will show on web-only demo ]

# %%
cshow(vfig)
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for my_ncview(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')))
# 		[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/senesi/tmp/climaf_cache/86/4.nc:
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:ncview "/home/senesi/tmp/climaf_cache/86/4.nc"

# %% [markdown]
# # 7- An advanced figure

# %% [markdown]
# ### 2nd plot : declare a script plot with PNG output. Here in NCL with a number of args for graphics settings

# %%
cscript('plotmap',\
        "ncl "+ cpath +"/../scripts/plotmap.ncl infile=${in} plotname=${out} \
                    cmap=${color} vmin=${min} vmax=${max} vdelta=${delta} var=${var} \
                    title=${crs} scale=${scale} offset=${offset} units=${units}; convert ${out} -trim ${out}",format="png")
# Out:
# [__init__   : operators.py, L. 186 ] : WARNING  : Redefining CliMAF script plotmap
# CliMAF operator : plotmap

# %% [markdown]
# ### Applying the operator - The only effect is to define a figure object

# %%
map=plotmap(tas_avg, min=260, max=300, delta=4)
map
# Out:
# plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), delta=4, max=300, min=260)

# %% [markdown]
# ### Require the figure as a file; this leads to actually compute it if needed (i.e. launch the script)

# %%
cfile(map)
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), delta=4, max=300, min=260)
# 		[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/senesi/tmp/climaf_cache/86/4.nc:
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:ncl /cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/plotmap.ncl infile='"/home/senesi/tmp/climaf_cache/86/4.nc"' plotname='"/home/senesi/tmp/climaf_cache/de/8.png"'                      vmin='260' vmax='300' vdelta='4' var='"tas"'                     title='"time_average(ds(example.AMIPV6ALB2G.tas.1980-1981.global.monthly)) - "'   ; convert "/home/senesi/tmp/climaf_cache/de/8.png" -trim "/home/senesi/tmp/climaf_cache/de/8.png"
# 	[register   : cache.py  , L. 124 ] : INFO     : plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), delta=4, max=300, min=260) registered as /home/senesi/tmp/climaf_cache/de/8.png
# 	[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 2 s with command:ncl /cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/plotmap.ncl infile='"/home/senesi/tmp/climaf_cache/86/4.nc"' plotname='"/home/senesi/tmp/climaf_cache/de/8.png"'                      vmin='260' vmax='300' vdelta='4' var='"tas"'                     title='"time_average(ds(example.AMIPV6ALB2G.tas.1980-1981.global.monthly)) - "'   ; convert "/home/senesi/tmp/climaf_cache/de/8.png" -trim "/home/senesi/tmp/climaf_cache/de/8.png"
# '/home/senesi/tmp/climaf_cache/de/8.png'

# %% [markdown]
# ### 'cshow' will display the figure using the file cache  [ Nothing will show on Web-only demo]

# %%
cshow(map)
# Out:
# 	[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), delta=4, max=300, min=260) is at /home/senesi/tmp/climaf_cache/de/8.png:

# %% [markdown]
# # 8- Mixing CliMAF basics and Python (and/or IPython)

# %% [markdown]
# ### A more realistic way of configuring the NCL-based plots, using Python features for graphics settings on the basis of on plotted variable

# %% [markdown]
# ### First define an auxiliary function

# %%
def map_graph_attributes(var) :
    rep=dict()
    rep["offset"]=0.
    rep["scale"]=1.
    rep["color"]="BlueDarkRed18"
    if var=='tas' :
        rep["offset"]=-273.15 ;  rep["scale"]=1.0 ; rep["units"]="C"
        rep["min"]=-30  ; rep["max"]=30 ; rep["delta"]=2.
    return rep

# %% [markdown]
# ### This allows to supply graphics attributes which are better tuned to the variable to display

# %%
map2=plotmap(tas_avg,crs="The Title",**map_graph_attributes(varOf(tas_avg)))
map2
# Out:
# plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), color='BlueDarkRed18', crs='The Title', delta=2.0, max=30, min=-30, offset=-273.15, scale=1.0, units='C')

# %% [markdown]
# ### Let launch the computation of the figure

# %%
figfile=cfile(map2) ; print(figfile)
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), color='BlueDarkRed18', crs='The Title', delta=2.0, max=30, min=-30, offset=-273.15, scale=1.0, units='C')
# 		[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/senesi/tmp/climaf_cache/86/4.nc:
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:ncl /cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/plotmap.ncl infile='"/home/senesi/tmp/climaf_cache/86/4.nc"' plotname='"/home/senesi/tmp/climaf_cache/97/0.png"'                     cmap='"BlueDarkRed18"' vmin='-30' vmax='30' vdelta='2.0' var='"tas"'                     title='"The Title"' scale='1.0' offset='-273.15' units='"C"'; convert "/home/senesi/tmp/climaf_cache/97/0.png" -trim "/home/senesi/tmp/climaf_cache/97/0.png"
# 	[register   : cache.py  , L. 124 ] : INFO     : plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), color='BlueDarkRed18', crs='The Title', delta=2.0, max=30, min=-30, offset=-273.15, scale=1.0, units='C') registered as /home/senesi/tmp/climaf_cache/97/0.png
# 	[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 2 s with command:ncl /cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/plotmap.ncl infile='"/home/senesi/tmp/climaf_cache/86/4.nc"' plotname='"/home/senesi/tmp/climaf_cache/97/0.png"'                     cmap='"BlueDarkRed18"' vmin='-30' vmax='30' vdelta='2.0' var='"tas"'                     title='"The Title"' scale='1.0' offset='-273.15' units='"C"'; convert "/home/senesi/tmp/climaf_cache/97/0.png" -trim "/home/senesi/tmp/climaf_cache/97/0.png"
# /home/senesi/tmp/climaf_cache/97/0.png

# %% [markdown]
# ### Bonus : using Ipython Notebook features for inline display

# %%
from IPython.display import Image
Image(filename=figfile)

# %% [markdown]
# # 9- Remapping data

# %% [markdown]
# ### For remapping a dataset to a named grid (known by cdo), let us use operator 'regridn'

# %%
dgr=regridn(tas_avg,cdogrid="r90x45") 
mapgr=plotmap(dgr, crs="2° Grid", min=260, max=300, delta=4)
Image(filename=cfile(mapgr))
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for plotmap(regridn(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), cdogrid='r90x45'), crs='2\xc2\xb0 Grid', delta=4, max=300, min=260)
# 		[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for regridn(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), cdogrid='r90x45')
# 			[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/senesi/tmp/climaf_cache/86/4.nc:
# 		[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/regrid.sh "/home/senesi/tmp/climaf_cache/86/4.nc" r90x45 /home/senesi/tmp/climaf_cache/96/1.nc
# 		[register   : cache.py  , L. 124 ] : INFO     : regridn(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), cdogrid='r90x45') registered as /home/senesi/tmp/climaf_cache/96/1.nc
# 		[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 0.7 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/regrid.sh "/home/senesi/tmp/climaf_cache/86/4.nc" r90x45 /home/senesi/tmp/climaf_cache/96/1.nc
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:ncl /cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/plotmap.ncl infile='"/home/senesi/tmp/climaf_cache/96/1.nc"' plotname='"/home/senesi/tmp/climaf_cache/6e/3.png"'                      vmin='260' vmax='300' vdelta='4' var='"tas"'                     title='"2° Grid"'   ; convert "/home/senesi/tmp/climaf_cache/6e/3.png" -trim "/home/senesi/tmp/climaf_cache/6e/3.png"
# 	[register   : cache.py  , L. 124 ] : INFO     : plotmap(regridn(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')), cdogrid='r90x45'), crs='2\xc2\xb0 Grid', delta=4, max=300, min=260) registered as /home/senesi/tmp/climaf_cache/6e/3.png
# 	[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 2 s with command:ncl /cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/plotmap.ncl infile='"/home/senesi/tmp/climaf_cache/96/1.nc"' plotname='"/home/senesi/tmp/climaf_cache/6e/3.png"'                      vmin='260' vmax='300' vdelta='4' var='"tas"'                     title='"2° Grid"'   ; convert "/home/senesi/tmp/climaf_cache/6e/3.png" -trim "/home/senesi/tmp/climaf_cache/6e/3.png"

# %% [markdown]
# ### An other way is to regrid to the grid of another dataset, with 'regrid'; Let us use the dataset defined earlier on a latlon box

# %%
dgr2=regrid(tas_ds, tas_ds_r) 
ncview(dgr2)
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for ncview(regrid(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly')))
# 		[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for regrid(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly'))
# 				[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: select(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/senesi/tmp/climaf_cache/da/c.nc:
# 				[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for select(ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly'))
# 				[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh "" /home/senesi/tmp/climaf_cache/26/f.nc "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "10,80,-50,40" "/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc"
# 				[register   : cache.py  , L. 124 ] : INFO     : select(ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly')) registered as /home/senesi/tmp/climaf_cache/26/f.nc
# 				[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 1 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh "" /home/senesi/tmp/climaf_cache/26/f.nc "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "10,80,-50,40" "/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc"
# 		[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/regrid.sh "/home/senesi/tmp/climaf_cache/da/c.nc" "/home/senesi/tmp/climaf_cache/26/f.nc" /home/senesi/tmp/climaf_cache/dd/5.nc
# 		[register   : cache.py  , L. 124 ] : INFO     : regrid(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly')) registered as /home/senesi/tmp/climaf_cache/dd/5.nc
# 		[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 0.7 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/regrid.sh "/home/senesi/tmp/climaf_cache/da/c.nc" "/home/senesi/tmp/climaf_cache/26/f.nc" /home/senesi/tmp/climaf_cache/dd/5.nc
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:ncview "/home/senesi/tmp/climaf_cache/dd/5.nc" 1>/dev/null 2>&1&
# ncview(regrid(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly')))

# %% [markdown]
# # 10- Computing an annual cycle

# %% [markdown]
# ### Let us compute an annual cycle, using swiss knife operator 'ccdo' (which applies cdo on a single dataset or object, with a cdo operator as argument), and look at it (nothing will show on Web only demo)

# %%
anncycle=ccdo(tas_ds,operator='ymonavg')
ncview(anncycle)
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for ncview(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'))
# 		[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg') is at /home/senesi/tmp/climaf_cache/a4/e.nc:
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:ncview "/home/senesi/tmp/climaf_cache/a4/e.nc" 1>/dev/null 2>&1&
# ncview(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'))

# %% [markdown]
# ### Define the average annual cycle on a latlon box using operator 'llbox', plot it (January will show), and display the plot

# %%
extract=llbox(anncycle, latmin=30, latmax=60, lonmin=-30, lonmax=30)
map_extract=plotmap(extract, min=260, max=300, delta=4)
Image(filename=cfile(map_extract))
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for plotmap(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'), latmax=60, latmin=30, lonmax=30, lonmin=-30), delta=4, max=300, min=260)
# 		[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'), latmax=60, latmin=30, lonmax=30, lonmin=-30)
# 			[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg')
# 			[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh ymonavg /home/senesi/tmp/climaf_cache/a4/e.nc "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc"
# 			[register   : cache.py  , L. 124 ] : INFO     : ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg') registered as /home/senesi/tmp/climaf_cache/a4/e.nc
# 			[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 1 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh ymonavg /home/senesi/tmp/climaf_cache/a4/e.nc "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc"
# 		[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh ""  /home/senesi/tmp/climaf_cache/33/9.nc "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" 30,60,-30,30 "/home/senesi/tmp/climaf_cache/a4/e.nc"
# 		[register   : cache.py  , L. 124 ] : INFO     : llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'), latmax=60, latmin=30, lonmax=30, lonmin=-30) registered as /home/senesi/tmp/climaf_cache/33/9.nc
# 		[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 0.7 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh ""  /home/senesi/tmp/climaf_cache/33/9.nc "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" 30,60,-30,30 "/home/senesi/tmp/climaf_cache/a4/e.nc"
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:ncl /cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/plotmap.ncl infile='"/home/senesi/tmp/climaf_cache/33/9.nc"' plotname='"/home/senesi/tmp/climaf_cache/70/3.png"'                      vmin='260' vmax='300' vdelta='4' var='"tas"'                     title='"llbox(ccdo(ds(example.AMIPV6ALB2G.tas.1980-1981.global.monthly), operator=ymonavg), latmax=60, latmin=30, lonmax=30, lonmin=-30) - "'   ; convert "/home/senesi/tmp/climaf_cache/70/3.png" -trim "/home/senesi/tmp/climaf_cache/70/3.png"
# 	[register   : cache.py  , L. 124 ] : INFO     : plotmap(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'), latmax=60, latmin=30, lonmax=30, lonmin=-30), delta=4, max=300, min=260) registered as /home/senesi/tmp/climaf_cache/70/3.png
# 	[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 2 s with command:ncl /cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/plotmap.ncl infile='"/home/senesi/tmp/climaf_cache/33/9.nc"' plotname='"/home/senesi/tmp/climaf_cache/70/3.png"'                      vmin='260' vmax='300' vdelta='4' var='"tas"'                     title='"llbox(ccdo(ds(example.AMIPV6ALB2G.tas.1980-1981.global.monthly), operator=ymonavg), latmax=60, latmin=30, lonmax=30, lonmin=-30) - "'   ; convert "/home/senesi/tmp/climaf_cache/70/3.png" -trim "/home/senesi/tmp/climaf_cache/70/3.png"

# %% [markdown]
# ### Let's compute the space average of annual cycle

# %%
space_average=ccdo(extract,operator='fldavg')

# %% [markdown]
# ### Creating a figure with standard operator timeplot

# %%
fig_avg=timeplot(space_average, title="Annual cycle")

# %% [markdown]
# ### Get the figure computed, and get its filename in CliMAF file cache

# %%
Image(filename=cfile(fig_avg))
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for timeplot(ccdo(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'), latmax=60, latmin=30, lonmax=30, lonmin=-30), operator='fldavg'), title='Annual cycle')
# 		[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for ccdo(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'), latmax=60, latmin=30, lonmax=30, lonmin=-30), operator='fldavg')
# 			[ceval      : driver.py , L. 214 ] : INFO     : Object found in cache: llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'), latmax=60, latmin=30, lonmax=30, lonmin=-30) is at /home/senesi/tmp/climaf_cache/33/9.nc:
# 		[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh fldavg /home/senesi/tmp/climaf_cache/97/0.nc "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "/home/senesi/tmp/climaf_cache/33/9.nc"
# 		[register   : cache.py  , L. 124 ] : INFO     : ccdo(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'), latmax=60, latmin=30, lonmax=30, lonmin=-30), operator='fldavg') registered as /home/senesi/tmp/climaf_cache/97/0.nc
# 		[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 0.7 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh fldavg /home/senesi/tmp/climaf_cache/97/0.nc "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "/home/senesi/tmp/climaf_cache/33/9.nc"
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/timeplot.sh "/home/senesi/tmp/climaf_cache/97/0.nc" /home/senesi/tmp/climaf_cache/ef/f.png "tas" Annual cycle
# 	[register   : cache.py  , L. 124 ] : INFO     : timeplot(ccdo(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'), operator='ymonavg'), latmax=60, latmin=30, lonmax=30, lonmin=-30), operator='fldavg'), title='Annual cycle') registered as /home/senesi/tmp/climaf_cache/ef/f.png
# 	[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 0.7 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/timeplot.sh "/home/senesi/tmp/climaf_cache/97/0.nc" /home/senesi/tmp/climaf_cache/ef/f.png "tas" Annual cycle

# %% [markdown]
# # 11- Derived variables, the easy way

# %% [markdown]
# ### Define a dataset using a variable name that is not in data files - i.e. a 'derived' variable

# %%
creShortTop=ds(experiment="AMIPV6ALB2G",variable="crest")

# %% [markdown]
# ### Declare a new 'CliMAF operator', to be used for computing the derived variable

# %%
cscript('minus','cdo sub ${in_1} ${in_2} ${out}')
# Out:
# [__init__   : operators.py, L. 186 ] : WARNING  : Redefining CliMAF script minus
# CliMAF operator : minus

# %% [markdown]
# ### Tell how the derived variable is derived using operator 'minus' with inputs defined as similar datasets with alternate variables

# %%
derive('crest','minus','rst','rstcs')

# %% [markdown]
# ### You can use the 'derived' dataset in any expression; computation will occur when needed

# %%
my_ncview(creShortTop)
# Out:
# 	[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for my_ncview(ds('example.AMIPV6ALB2G.crest.1980-1981.global.monthly'))
# 			[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for minus(ds('example.AMIPV6ALB2G.rst.1980-1981.global.monthly'), ds('example.AMIPV6ALB2G.rstcs.1980-1981.global.monthly'))
# 					[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for select(ds('example.AMIPV6ALB2G.rst.1980-1981.global.monthly'))
# 					[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh "" /home/senesi/tmp/climaf_cache/38/0.nc "rst" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc"
# 					[register   : cache.py  , L. 124 ] : INFO     : select(ds('example.AMIPV6ALB2G.rst.1980-1981.global.monthly')) registered as /home/senesi/tmp/climaf_cache/38/0.nc
# 					[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 1 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh "" /home/senesi/tmp/climaf_cache/38/0.nc "rst" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc"
# 					[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for select(ds('example.AMIPV6ALB2G.rstcs.1980-1981.global.monthly'))
# 					[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh "" /home/senesi/tmp/climaf_cache/c3/9.nc "rstcs" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc"
# 					[register   : cache.py  , L. 124 ] : INFO     : select(ds('example.AMIPV6ALB2G.rstcs.1980-1981.global.monthly')) registered as /home/senesi/tmp/climaf_cache/c3/9.nc
# 					[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 0.8 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh "" /home/senesi/tmp/climaf_cache/c3/9.nc "rstcs" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "/cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1980.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc /cnrm/aster/data3/aster/senesi/dev/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc"
# 			[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:cdo sub "/home/senesi/tmp/climaf_cache/38/0.nc" "/home/senesi/tmp/climaf_cache/c3/9.nc" /home/senesi/tmp/climaf_cache/ed/8.nc
# 			[register   : cache.py  , L. 124 ] : INFO     : minus(ds('example.AMIPV6ALB2G.rst.1980-1981.global.monthly'), ds('example.AMIPV6ALB2G.rstcs.1980-1981.global.monthly')) registered as /home/senesi/tmp/climaf_cache/ed/8.nc
# 			[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 0.6 s with command:cdo sub "/home/senesi/tmp/climaf_cache/38/0.nc" "/home/senesi/tmp/climaf_cache/c3/9.nc" /home/senesi/tmp/climaf_cache/ed/8.nc
# 	[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:ncview "/home/senesi/tmp/climaf_cache/ed/8.nc"
# my_ncview(ds('example.AMIPV6ALB2G.crest.1980-1981.global.monthly'))

# %% [markdown]
# # 12- CliMAF access to data organized according to CMIP5 DRS

# %% [markdown]
# ### This example will work as is on CNRM's Lustre and on IPSL's Ciclad, and can be easily tuned to other local CMIP5 datasets

# %% [markdown]
# ### First, let us declare a list of data for CNRM-CM CMIP5 data at theses sites (note : this is actually built-in , and not necessary)

# %%
urls_CMIP5_CNRM=["/cnrm/aster/data2/ESG/data1", "/cnrm/aster/data2/ESG/data2", "/cnrm/aster/data2/ESG/data5",
      "/cnrm/aster/data4/ESG/data6", "/cnrm/aster/data4/ESG/data7", "/cnrm/aster/data4/ESG/data8"]

urls_CMIP5_Ciclad=["/prodigfs/esg"]

# %% [markdown]
# ### Declare locations for searching data for all projects, experiment and frequencies, and that data located in dirs listed in urls_CMIP5_CNRM and urls_CMIP5_Ciclad is organized as 'CMIP5_DRS'

# %%
dataloc(project="CMIP5", organization="CMIP5_DRS", url=urls_CMIP5_CNRM+urls_CMIP5_Ciclad)
# Out:
# <climaf.dataloc.dataloc instance at 0x7fc1d44bec68>

# %% [markdown]
# ### Define a default value for some dataset facets

# %%
cdef("frequency","monthly") ;  cdef("project","CMIP5")

# %% [markdown]
# ### Define your dataset (a number of facets take default values)

# %%
tas1pc=ds(model="CNRM-CM5", experiment="1pctCO2", variable="tas", period="1860-1861")

# %% [markdown]
# ###  Display the basic filenames involved in the dataset (all filenames in one single string). CliMAF will search them at the data location which is the most specific among all declared data locations

# %%
files=tas1pc.baseFiles()
print files
# Out:
# /cnrm/aster/data2/ESG/data1/CMIP5/output1/CNRM-CERFACS/CNRM-CM5/1pctCO2/mon/atmos/Amon/r1i1p1/v20110701/tas/tas_Amon_CNRM-CM5_1pctCO2_r1i1p1_185001-189912.nc

# %% [markdown]
# ### Let CliMAF generate a file with the exact dataset in its disk cache (select period and/or variables, aggregate files...)

# %%
my_file=cfile(tas1pc)
print my_file
# Out:
# 		[ceval      : driver.py , L. 253 ] : INFO     : nothing relevant found in cache for select(ds('CMIP5.1pctCO2.tas.1860-1861.global.CNRM-CM5.r1i1p1.monthly.*.*.last'))
# 		[ceval_scri : driver.py , L. 438 ] : INFO     : Launching command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh "" /home/senesi/tmp/climaf_cache/1b/8.nc "tas" "1860-01-01T00:00:00,1861-12-31T23:59:00" "" "/cnrm/aster/data2/ESG/data1/CMIP5/output1/CNRM-CERFACS/CNRM-CM5/1pctCO2/mon/atmos/Amon/r1i1p1/v20110701/tas/tas_Amon_CNRM-CM5_1pctCO2_r1i1p1_185001-189912.nc"
# 		[register   : cache.py  , L. 124 ] : INFO     : select(ds('CMIP5.1pctCO2.tas.1860-1861.global.CNRM-CM5.r1i1p1.monthly.*.*.last')) registered as /home/senesi/tmp/climaf_cache/1b/8.nc
# 		[ceval_scri : driver.py , L. 452 ] : INFO     : Done in 2 s with command:/cnrm/aster/data3/aster/senesi/dev/climaf/climaf/../scripts/mcdo.sh "" /home/senesi/tmp/climaf_cache/1b/8.nc "tas" "1860-01-01T00:00:00,1861-12-31T23:59:00" "" "/cnrm/aster/data2/ESG/data1/CMIP5/output1/CNRM-CERFACS/CNRM-CM5/1pctCO2/mon/atmos/Amon/r1i1p1/v20110701/tas/tas_Amon_CNRM-CM5_1pctCO2_r1i1p1_185001-189912.nc"
# /home/senesi/tmp/climaf_cache/1b/8.nc

# %% [markdown]
# # Much more at http://climaf.readthedocs.org.

# %% [markdown]
# ## Installing is easy.

# %% [markdown]
# ## You may use and/or contribute at various levels.
