# %% [markdown]
# # CliMAF tour

# %% [markdown]
# # CliMAF is a framework for Climate Model Assessment. It allows to combine diagnostic binaries, scripts and Python functions as easily as possible

# %% [markdown]
# ## Here  : defining a dataset and its location, defining and using operators based on external scripts/binaries or Python functions, assembling all, illustrating cache features, plotting and 'exporting' results (as files or MaskedArrays)

# %% [markdown]
# ### Init CliMAF

# %%
from climaf.api import *
# Out:
# Climaf version = 0.12
# Cache directory set to : ~/tmp/climaf_cache (use $CLIMAF_CACHE if set)
# Available macros read from ~/.climaf.macros are : []

# %% [markdown]
# ### For the sake of the demo , tell CliMAF to be a bit verbose (both on stderr and on logging file), and erase any previous result

# %%
clog('info')
clog_file('debug')
craz()

# %% [markdown]
# # 1- Data location and datasets

# %% [markdown]
# ### Declare data organization a given 'project' (usually done in config files)

# %%
dataloc(project="example",organization="generic",url=[\
        cpath+"/../examples/data/${simulation}/L/${simulation}SFXYYYY.nc", \
        cpath+"/../examples/data/${simulation}/A/${simulation}PLYYYY.nc"])
# Out:
# <climaf.dataloc.dataloc instance at 0x7f36dc086ab8>

# %% [markdown]
# ### Define a default value for some dataset facets

# %%
cdef("project","example")
cdef("period","1980-1981")

# %% [markdown]
# ### Define a dataset based on the experiment defined above (this uses the facets default values)

# %%
tas_ds=ds(simulation="AMIPV6ALB2G", variable="tas")

# %% [markdown]
# ### You can also define a dataset restricted to a latlon box

# %%
tas_ds_r=ds(simulation="AMIPV6ALB2G", variable="tas", domain=[10,80,-50,40])

# %% [markdown]
# ### Have a look at dataset's symbolic expression (other patterns could apply , according to project's "DRS")

# %%
tas_ds_r
# Out:
# ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly')

# %% [markdown]
# # 2- CliMAF manages the access to the data for a number of organizations

# %% [markdown]
# ### CliMAF can identify all the files relevant to the dataset (see CMIP5 DRS case further below, § 12)

# %%
tas_ds.baseFiles()
# Out:
# '/cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc'

# %% [markdown]
# ### You can display the header information of a CliMAF object (which is a netCDF file)

# %%
ncdump(tas_ds)
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for ncdump(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'))
# 			[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for select(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'))
# 			[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "" "/home/vignonl/tmp/climaf_cache/da/c.nc" "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "" "" "" /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc
# 			[register   : cache.py  , L. 149 ] : INFO     : select(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) registered as /home/vignonl/tmp/climaf_cache/da/c.nc
# Done in 0.5 s with script computation for select(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'))
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:ncdump -h /home/vignonl/tmp/climaf_cache/da/c.nc
# netcdf c {
# dimensions:
# 	lon = 256 ;
# 	lat = 128 ;
# 	time = UNLIMITED ; // (36 currently)
# variables:
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "days since 1975-01-01 00:00:00" ;
# 		time:calendar = "standard" ;
# 	float tas(time, lat, lon) ;
# 		tas:long_name = "2m_Temperature" ;
# 		tas:units = "K" ;
# 		tas:grid_type = "gaussian" ;
# 		tas:_FillValue = 1.e+20f ;
# 		tas:missing_value = 1.e+20f ;
# 		tas:comment = "instantaneous values" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.6.9 (http://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.0" ;
# 		:history = "Thu Dec 03 15:10:29 2015: cdo copy climaf_mcdo_6gJW5r/AMIPV6ALB2GSFX1980.nc climaf_mcdo_6gJW5r/AMIPV6ALB2GSFX1981.nc climaf_mcdo_6gJW5r/AMIPV6ALB2GSFX1981.nc climaf_mcdo_6gJW5r/mcdo.sh.nc\n",
# 			"Thu Dec 03 15:10:29 2015: cdo -f nc seldate,1980-01-01T00:00:00,1981-12-31T23:59:00 -selname,tas /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc climaf_mcdo_6gJW5r/AMIPV6ALB2GSFX1980.nc\n",
# 			"Mon Feb 16 16:03:44 2015: cdo selvar,tas,tasmin,tasmax,hfls,hfss AMIPV6ALB2GSFX1980.nc AMIPV6ALB2GSFX1980e.nc\n",
# 			"Thu Apr 10 07:47:44 2014: ncrcat -n 12,2,1 AMIPV6ALB2GSFX198001.nc AMIPV6ALB2GSFX1980.nc\n",
# 			"created at time: Thu Apr 10 07:47:07 2014" ;
# 		:institution = "CNRM (Centre National de Recherches Meteorologiques, Meteo-France, Toulouse, France)" ;
# 		:title = "[EXPE]" ;
# 		:nco_openmp_thread_number = 1 ;
# 		:CDO = "Climate Data Operators version 1.6.9 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'example.AMIPV6ALB2G.tas.1980-1981.global.monthly\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 0.12 (http://climaf.rtfd.org)" ;
# }
# ncdump(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'))

# %% [markdown]
# ### It can also hande other organizations : CMIP5 DRS, EM, OBS4MIPs at CNRM, OCMIP5 on IPSL's Ciclad, CAMI obs at CNRM

# %% [markdown]
# # 4- Using external scripts and binaries for implementing diagnostics

# %% [markdown]
# ### First diagnostic is basic climatology - Let us declare a 'CliMAF operator' for this diag, using an external script and some keywords conventions

# %%
cscript('time_average' ,cpath+'/../scripts/time_average_basics.sh ${out} ${in}' )
# Out:
# [__init__   : operators.py, L. 238 ] : WARNING  : Redefining CliMAF script time_average
# CliMAF operator : time_average

# %% [markdown]
# ### Let us have a look at the script involved : this one is pure bash wrapping around CDO calls

# %%
# %load ../scripts/time_average_basics.sh

# %%
#!/bin/bash
# Applies the timavg cdo operator to a list of FILES 
# Puts results in OUT 
# Exit with non-0 status if any problem

set -ex 
out=$1
files=$2
cdo timavg $files $out

# %% [markdown]
# ### Declaring a 'CliMAF operator' actually creates a Python function

# %%
time_average
# Out:
# <function climaf.operators.time_average>

# %% [markdown]
# ### A doc string is available for each 'operator function' (the same as for on-line doc)

# %%
help(time_average)
# Out:
# Help on function time_average in module climaf.operators:
#
# time_average(*args, **dic)
#     time_average : compute time average for all time steps
#     -------------------------------------------------------
#
#     Apply operator timavg on the object/dataset to another grid, using CDO
#
#     **References** : https://code.zmaw.de/projects/cdo/embedded/1.6.4/cdo.html#x1-3560002.8.14
#
#     **Provider / contact** : climaf at meteo dot fr
#
#     **Inputs** (in the order of CliMAF call):
#       - any dataset (but only one)
#
#     **Mandatory arguments**: none
#
#     **Optional arguments**: none
#
#     **Output** : the time-averaged object
#
#     **Climaf call example** ::
#
#       >>> ds= .... #some dataset, with whatever variable
#       >>> ds_tavg=time_average(ds)
#
#     **Side effects** : None
#
#     **Implementation** : CDO call with operator ``timavg``,  through script mcdo.sh

# %% [markdown]
# ### Symbolically apply the script to a dataset, using the 'CliMAF operator', and have a look at object/symbol result

# %%
tas_avg=time_average(tas_ds)
tas_avg
# Out:
# time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'))

# %% [markdown]
# # 5- From CliMAF objects to files or Masked Array

# %% [markdown]
# ### Computation actually occurs when wanting to 'export' objects in some way : here as a file using 'cfile'

# %%
cfile(tas_avg)
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'))
# 			[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: select(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/vignonl/tmp/climaf_cache/da/c.nc:
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/time_average_basics.sh /home/vignonl/tmp/climaf_cache/86/4.nc /home/vignonl/tmp/climaf_cache/da/c.nc
# 	[register   : cache.py  , L. 149 ] : INFO     : time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) registered as /home/vignonl/tmp/climaf_cache/86/4.nc
# Done in 0.1 s with script computation for time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'))
# '/home/vignonl/tmp/climaf_cache/86/4.nc'

# %% [markdown]
# ### The file cache will be used whenever the same object is requested (or even for an included objet). Here, in addition, we request a copy of the cache file, at some location

# %%
cfile(tas_ds,"~/tmp/tasavg.nc")
# Out:
# 		[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: select(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/vignonl/tmp/climaf_cache/da/c.nc:
# '/home/vignonl/tmp/tasavg.nc'

# %% [markdown]
# ### Another export format : MaskedArrays (others could apply, as e.g. CDAT's MV)

# %%
tas_avg_MA=cMA(tas_avg)
# Out:
# 	[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/vignonl/tmp/climaf_cache/86/4.nc:

# %% [markdown]
# ### Looking at the result

# %%
type(tas_avg_MA)
# Out:
# numpy.ma.core.MaskedArray

# %%
tas_avg_MA.shape
# Out:
# (1, 128, 256)

# %% [markdown]
# # 6- Display a simple figure

# %% [markdown]
# ### Plot the data, first way : let us declare a 'CliMAF operator', for using binary 'ncview', and with output format == None

# %%
cscript('my_ncview' ,'ncview ${in}' , format=None)
# Out:
# CliMAF operator : my_ncview

# %% [markdown]
# ### As a special case, apply such an operator also launches the computation, which here means to display [ Nothing will show on web-only demo ]

# %%
vfig=my_ncview(tas_avg)
vfig
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for my_ncview(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')))
# 		[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/vignonl/tmp/climaf_cache/86/4.nc:
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:ncview /home/vignonl/tmp/climaf_cache/86/4.nc
# my_ncview(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')))

# %% [markdown]
# ### The vfig 'object' can also be shown again using cshow  [ Again - Nothing will show on web-only demo ]

# %%
cshow(vfig)
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for my_ncview(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')))
# 		[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/vignonl/tmp/climaf_cache/86/4.nc:
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:ncview /home/vignonl/tmp/climaf_cache/86/4.nc

# %% [markdown]
# # 7- An advanced figure

# %% [markdown]
# ### 2nd plot : declare a script plot with PNG output. Here in NCL with a number of args for graphics settings

# %%
cscript('plotmap',\
        '(ncl '+ cpath +'/../scripts/plotmap.ncl infile=\'\"${in}\"\' plotname=\'\"${out}\"\' \
                    cmap=\'\"${color}\"\' vmin=${min} vmax=${max} vdelta=${delta} var=\'\"${var}\"\' \
                    title=\'\"${title}\"\' scale=${scale} offset=${offset} units=\'\"${units}\"\' \
                    && convert ${out} -trim ${out} )',format="png")
# Out:
# CliMAF operator : plotmap

# %% [markdown]
# ### Applying the operator - The only effect is to define a figure object

# %%
map=plotmap(tas_avg, min=260, max=300, delta=4, title="my title")
map
# Out:
# plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),delta=4,max=300,min=260,title='test')

# %% [markdown]
# ### Require the figure as a file; this leads to actually compute it if needed (i.e. launch the script)

# %%
cfile(map)
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),delta=4,max=300,min=260,title='test')
# 		[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/vignonl/tmp/climaf_cache/86/4.nc:
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:(ncl /cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/plotmap.ncl infile='"/home/vignonl/tmp/climaf_cache/86/4.nc"' plotname='"/home/vignonl/tmp/climaf_cache/3d/9.png"'                      vmin=260 vmax=300 vdelta=4 var='"tas"'                     title='"test"'                        && convert /home/vignonl/tmp/climaf_cache/3d/9.png -trim /home/vignonl/tmp/climaf_cache/3d/9.png )
# 	[register   : cache.py  , L. 149 ] : INFO     : plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),delta=4,max=300,min=260,title='test') registered as /home/vignonl/tmp/climaf_cache/3d/9.png
# Done in 1.2 s with script computation for plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),delta=4,max=300,min=260,title='test')
# '/home/vignonl/tmp/climaf_cache/3d/9.png'

# %% [markdown]
# ### 'cshow' will display the figure using the file cache  [ Nothing will show on Web-only demo]

# %%
cshow(map)
# Out:
# 	[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),delta=4,max=300,min=260,title='test') is at /home/vignonl/tmp/climaf_cache/3d/9.png:

# %% [markdown]
# # 8- Mixing CliMAF basics and Python (and/or IPython)

# %% [markdown]
# ### A more realistic way of configuring the NCL-based plots, using Python features for graphics settings on the basis of on plotted variable

# %% [markdown]
# ### First define an auxiliary function

# %%
def map_graph_attributes(var) :
    rep=dict()
    rep["offset"]=0.
    rep["scale"]=1.
    rep["color"]="BlueDarkRed18"
    if var=='tas' :
        rep["offset"]=-273.15 ;  rep["scale"]=1.0 ; rep["units"]="C"
        rep["min"]=-30  ; rep["max"]=30 ; rep["delta"]=2.
    return rep

# %% [markdown]
# ### This allows to supply graphics attributes which are better tuned to the variable to display

# %%
map2=plotmap(tas_avg,title="The Title",**map_graph_attributes(varOf(tas_avg)))
map2
# Out:
# plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),color='BlueDarkRed18',delta=2.0,max=30,min=-30,offset=-273.15,scale=1.0,title='The Title',units='C')

# %% [markdown]
# ### Let launch the computation of the figure

# %%
figfile=cfile(map2) ; print(figfile)
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),color='BlueDarkRed18',delta=2.0,max=30,min=-30,offset=-273.15,scale=1.0,title='The Title',units='C')
# 		[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/vignonl/tmp/climaf_cache/86/4.nc:
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:(ncl /cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/plotmap.ncl infile='"/home/vignonl/tmp/climaf_cache/86/4.nc"' plotname='"/home/vignonl/tmp/climaf_cache/3e/b.png"'                     cmap='"BlueDarkRed18"' vmin=-30 vmax=30 vdelta=2.0 var='"tas"'                     title='"The Title"' scale=1.0 offset=-273.15 units='"C"'                     && convert /home/vignonl/tmp/climaf_cache/3e/b.png -trim /home/vignonl/tmp/climaf_cache/3e/b.png )
# 	[register   : cache.py  , L. 149 ] : INFO     : plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),color='BlueDarkRed18',delta=2.0,max=30,min=-30,offset=-273.15,scale=1.0,title='The Title',units='C') registered as /home/vignonl/tmp/climaf_cache/3e/b.png
# /home/vignonl/tmp/climaf_cache/3e/b.png
# Done in 1.2 s with script computation for plotmap(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),color='BlueDarkRed18',delta=2.0,max=30,min=-30,offset=-273.15,scale=1.0,title='The Title',units='C')

# %% [markdown]
# ### Bonus : using Ipython Notebook features for inline display

# %%
from IPython.display import Image
Image(filename=figfile)

# %% [markdown]
# # 9- Remapping data

# %% [markdown]
# ### For remapping a dataset to a named grid (known by cdo), let us use operator 'regridn'

# %%
dgr=regridn(tas_avg,cdogrid="r90x45") 
mapgr=plotmap(dgr, title="2° Grid", min=260, max=300, delta=4)
Image(filename=cfile(mapgr))
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for plotmap(regridn(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),cdogrid='r90x45'),delta=4,max=300,min=260,title='2\xc2\xb0 Grid')
# 		[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for regridn(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),cdogrid='r90x45')
# 			[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/vignonl/tmp/climaf_cache/86/4.nc:
# 		[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/regrid.sh /home/vignonl/tmp/climaf_cache/86/4.nc r90x45 /home/vignonl/tmp/climaf_cache/5e/7.nc
# 		[register   : cache.py  , L. 149 ] : INFO     : regridn(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),cdogrid='r90x45') registered as /home/vignonl/tmp/climaf_cache/5e/7.nc
# Done in 0.1 s with script computation for regridn(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),cdogrid='r90x45')
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:(ncl /cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/plotmap.ncl infile='"/home/vignonl/tmp/climaf_cache/5e/7.nc"' plotname='"/home/vignonl/tmp/climaf_cache/2f/c.png"'                      vmin=260 vmax=300 vdelta=4 var='"tas"'                     title='"2° Grid"'                        && convert /home/vignonl/tmp/climaf_cache/2f/c.png -trim /home/vignonl/tmp/climaf_cache/2f/c.png )
# 	[register   : cache.py  , L. 149 ] : INFO     : plotmap(regridn(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),cdogrid='r90x45'),delta=4,max=300,min=260,title='2\xc2\xb0 Grid') registered as /home/vignonl/tmp/climaf_cache/2f/c.png
# Done in 1.1 s with script computation for plotmap(regridn(time_average(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')),cdogrid='r90x45'),delta=4,max=300,min=260,title='2\xc2\xb0 Grid')

# %% [markdown]
# ### An other way is to regrid to the grid of another dataset, with 'regrid'; Let us use the dataset defined earlier on a latlon box

# %%
dgr2=regrid(tas_ds, tas_ds_r) 
ncview(dgr2)
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for ncview(regrid(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly')))
# 		[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for regrid(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly'))
# 				[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: select(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly')) is at /home/vignonl/tmp/climaf_cache/da/c.nc:
# 				[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for select(ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly'))
# 				[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "" "/home/vignonl/tmp/climaf_cache/26/f.nc" "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "10,80,-50,40" "" "" "" /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc
# 				[register   : cache.py  , L. 149 ] : INFO     : select(ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly')) registered as /home/vignonl/tmp/climaf_cache/26/f.nc
# Done in 0.3 s with script computation for select(ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly'))
# 		[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/regrid.sh /home/vignonl/tmp/climaf_cache/da/c.nc /home/vignonl/tmp/climaf_cache/26/f.nc /home/vignonl/tmp/climaf_cache/09/8.nc
# 		[register   : cache.py  , L. 149 ] : INFO     : regrid(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly')) registered as /home/vignonl/tmp/climaf_cache/09/8.nc
# Done in 0.1 s with script computation for regrid(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly'))
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:ncview /home/vignonl/tmp/climaf_cache/09/8.nc 1>/dev/null 2>&1&
# ncview(regrid(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),ds('example.AMIPV6ALB2G.tas.1980-1981.[10, 80, -50, 40].monthly')))

# %% [markdown]
# # 10- Computing an annual cycle

# %% [markdown]
# ### Let us compute an annual cycle, using swiss knife operator 'ccdo' (which applies cdo on a single dataset or object, with a cdo operator as argument), and look at it (nothing will show on Web only demo)

# %%
anncycle=ccdo(tas_ds,operator='ymonavg')
ncview(anncycle)
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for ncview(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'))
# 		[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg')
# 		[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "ymonavg" "/home/vignonl/tmp/climaf_cache/ee/1.nc" "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "" "" "" /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1980.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/L/AMIPV6ALB2GSFX1981.nc
# 		[register   : cache.py  , L. 149 ] : INFO     : ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg') registered as /home/vignonl/tmp/climaf_cache/ee/1.nc
# Done in 0.4 s with script computation for ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg')
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:ncview /home/vignonl/tmp/climaf_cache/ee/1.nc 1>/dev/null 2>&1&
# ncview(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'))

# %% [markdown]
# ### Define the average annual cycle on a latlon box using operator 'llbox', plot it (January will show), and display the plot

# %%
extract=llbox(anncycle, latmin=30, latmax=60, lonmin=-30, lonmax=30)
map_extract=plotmap(extract, min=260, max=300, delta=4)
Image(filename=cfile(map_extract))
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for plotmap(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30),delta=4,max=300,min=260)
# 		[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30)
# 			[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg') is at /home/vignonl/tmp/climaf_cache/ee/1.nc:
# 		[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh ""  "/home/vignonl/tmp/climaf_cache/73/5.nc" "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "30,60,-30,30" "" "" "" /home/vignonl/tmp/climaf_cache/ee/1.nc
# 		[register   : cache.py  , L. 149 ] : INFO     : llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30) registered as /home/vignonl/tmp/climaf_cache/73/5.nc
# Done in 0.1 s with script computation for llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30)
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:(ncl /cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/plotmap.ncl infile='"/home/vignonl/tmp/climaf_cache/73/5.nc"' plotname='"/home/vignonl/tmp/climaf_cache/9e/b.png"'                      vmin=260 vmax=300 vdelta=4 var='"tas"'                     title='"llbox(ccdo(ds(example.AMIPV6ALB2G.tas.1980-1981.global.monthly),operator=ymonavg),latmax=60,latmin=30,lonmax=30,lonmin=-30) - "'                        && convert /home/vignonl/tmp/climaf_cache/9e/b.png -trim /home/vignonl/tmp/climaf_cache/9e/b.png )
# 	[register   : cache.py  , L. 149 ] : INFO     : plotmap(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30),delta=4,max=300,min=260) registered as /home/vignonl/tmp/climaf_cache/9e/b.png
# Done in 1.0 s with script computation for plotmap(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30),delta=4,max=300,min=260)

# %% [markdown]
# ### Let's compute the space average of annual cycle

# %%
space_average=ccdo(extract,operator='fldavg')

# %% [markdown]
# ### Creating a figure with standard operator timeplot

# %%
fig_avg=lines(space_average, title="Annual cycle")

# %% [markdown]
# ### Get the figure computed, and get its filename in CliMAF file cache

# %%
Image(filename=cfile(fig_avg))
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for lines(ccdo(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30),operator='fldavg'),title='Annual cycle')
# 		[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for ccdo(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30),operator='fldavg')
# 			[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30) is at /home/vignonl/tmp/climaf_cache/73/5.nc:
# 		[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "fldavg" "/home/vignonl/tmp/climaf_cache/53/4.nc" "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "" "" "" /home/vignonl/tmp/climaf_cache/73/5.nc
# 		[register   : cache.py  , L. 149 ] : INFO     : ccdo(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30),operator='fldavg') registered as /home/vignonl/tmp/climaf_cache/53/4.nc
# Done in 0.1 s with script computation for ccdo(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30),operator='fldavg')
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:(ncl -Q /cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/lineplot.ncl infile='"/home/vignonl/tmp/climaf_cache/53/4.nc"' plotname='"/home/vignonl/tmp/climaf_cache/ae/1.png"' var='"tas"' title='"Annual cycle"'         && convert /home/vignonl/tmp/climaf_cache/ae/1.png -trim /home/vignonl/tmp/climaf_cache/ae/1.png)
# 	[register   : cache.py  , L. 149 ] : INFO     : lines(ccdo(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30),operator='fldavg'),title='Annual cycle') registered as /home/vignonl/tmp/climaf_cache/ae/1.png
# Done in 0.8 s with script computation for lines(ccdo(llbox(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),latmax=60,latmin=30,lonmax=30,lonmin=-30),operator='fldavg'),title='Annual cycle')

# %% [markdown]
# ### Computation of seasonal average and plot bias with 'plot', a general purpose plot operator (for plotting 1D and 2D datasets: maps, cross-sections and profiles)

# %%
# obs
obs=ds(project='cruts3',variable='tas', period='1980-1981',grid='T127')
anncycle_obs=ccdo(obs,operator='ymonavg')

# %%
# seasonal average
JFM=ccdo(anncycle,operator='selmon,1,2,3')
JAS=ccdo(anncycle,operator='selmon,7,8,9')

JFM_obs=ccdo(anncycle_obs,operator='selmon,1,2,3')
JAS_obs=ccdo(anncycle_obs,operator='selmon,7,8,9')

# %%
# bias
JFM_regrid=regrid(JFM,JFM_obs)
JFM_bias=minus(JFM_regrid,JFM_obs)

JAS_regrid=regrid(JAS,JAS_obs)
JAS_bias=minus(JAS_regrid,JAS_obs)

# %%
# plot
JFM_map=plot(JFM,title='JFM',contours=1)
JAS_map=plot(JAS,title='JAS', contours=1)

#JFM_obs_map=plot(JFM_obs,title='JFM')
#JAS_obs_map=plot(JAS_obs,title='JAS')

JFM_bias_map=plot(JFM_bias,title='Bias JFM')
JAS_bias_map=plot(JAS_bias,title='Bias JAS')

multiplot=cpage([[JFM_map, JAS_map],[JFM_bias_map,JAS_bias_map]],heights=[0.2, 0.2])
Image(filename=cfile(multiplot))
# Out:
# 		[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for plot(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),contours=1,title='JFM')
# 			[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3')
# 				[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg') is at /home/vignonl/tmp/climaf_cache/ee/1.nc:
# 			[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "selmon,1,2,3" "/home/vignonl/tmp/climaf_cache/15/4.nc" "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "" "" "" /home/vignonl/tmp/climaf_cache/ee/1.nc
# 			[register   : cache.py  , L. 149 ] : INFO     : ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3') registered as /home/vignonl/tmp/climaf_cache/15/4.nc
# Done in 0.2 s with script computation for ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3')
# 		[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:(ncl -Q /cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/gplot.ncl main_file='"/home/vignonl/tmp/climaf_cache/15/4.nc"'     plotname='"/home/vignonl/tmp/climaf_cache/33/b.png"'     main_var='"tas"'    title='"JFM"'               contours='"1"'                     )
# 		[register   : cache.py  , L. 149 ] : INFO     : plot(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),contours=1,title='JFM') registered as /home/vignonl/tmp/climaf_cache/33/b.png
# Done in 1.0 s with script computation for plot(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),contours=1,title='JFM')
# 		[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for plot(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),contours=1,title='JAS')
# 			[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9')
# 				[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg') is at /home/vignonl/tmp/climaf_cache/ee/1.nc:
# 			[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "selmon,7,8,9" "/home/vignonl/tmp/climaf_cache/b4/1.nc" "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "" "" "" /home/vignonl/tmp/climaf_cache/ee/1.nc
# 			[register   : cache.py  , L. 149 ] : INFO     : ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9') registered as /home/vignonl/tmp/climaf_cache/b4/1.nc
# Done in 0.2 s with script computation for ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9')
# 		[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:(ncl -Q /cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/gplot.ncl main_file='"/home/vignonl/tmp/climaf_cache/b4/1.nc"'     plotname='"/home/vignonl/tmp/climaf_cache/9b/d.png"'     main_var='"tas"'    title='"JAS"'               contours='"1"'                     )
# 		[register   : cache.py  , L. 149 ] : INFO     : plot(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),contours=1,title='JAS') registered as /home/vignonl/tmp/climaf_cache/9b/d.png
# Done in 1.0 s with script computation for plot(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),contours=1,title='JAS')
# 		[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for plot(minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),title='Bias JFM')
# 			[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3'))
# 				[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3'))
# 					[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3') is at /home/vignonl/tmp/climaf_cache/15/4.nc:
# 					[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')
# 						[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg')
# 						[selectGene : dataloc.py, L. 334 ] : WARNING  : Cannot yet filter files re. time using only file content. TBD
# 						[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "ymonavg" "/home/vignonl/tmp/climaf_cache/fc/7.nc" "tmp" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "tas,tmp,1,273.1" "K" "" /cnrm/vdr/DATA/OBS/netcdf/monthly_mean/cruts3/tmp_cru_ts_3.T127.nc
# 						[register   : cache.py  , L. 149 ] : INFO     : ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg') registered as /home/vignonl/tmp/climaf_cache/fc/7.nc
# Done in 1.9 s with script computation for ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg')
# 					[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "selmon,1,2,3" "/home/vignonl/tmp/climaf_cache/30/1.nc" "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "" "" "" /home/vignonl/tmp/climaf_cache/fc/7.nc
# 					[register   : cache.py  , L. 149 ] : INFO     : ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3') registered as /home/vignonl/tmp/climaf_cache/30/1.nc
# Done in 0.2 s with script computation for ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')
# 				[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/regrid.sh /home/vignonl/tmp/climaf_cache/15/4.nc /home/vignonl/tmp/climaf_cache/30/1.nc /home/vignonl/tmp/climaf_cache/f9/c.nc
# 				[register   : cache.py  , L. 149 ] : INFO     : regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')) registered as /home/vignonl/tmp/climaf_cache/f9/c.nc
# Done in 0.1 s with script computation for regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3'))
# 				[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3') is at /home/vignonl/tmp/climaf_cache/30/1.nc:
# 			[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:cdo sub /home/vignonl/tmp/climaf_cache/f9/c.nc /home/vignonl/tmp/climaf_cache/30/1.nc /home/vignonl/tmp/climaf_cache/ff/b.nc
# 			[register   : cache.py  , L. 149 ] : INFO     : minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')) registered as /home/vignonl/tmp/climaf_cache/ff/b.nc
# Done in 0.1 s with script computation for minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3'))
# 		[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:(ncl -Q /cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/gplot.ncl main_file='"/home/vignonl/tmp/climaf_cache/ff/b.nc"'     plotname='"/home/vignonl/tmp/climaf_cache/08/a.png"'     main_var='"tas"'    title='"Bias JFM"'                                    )
# 		[register   : cache.py  , L. 149 ] : INFO     : plot(minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),title='Bias JFM') registered as /home/vignonl/tmp/climaf_cache/08/a.png
# Done in 1.0 s with script computation for plot(minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),title='Bias JFM')
# 		[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for plot(minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),title='Bias JAS')
# 			[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9'))
# 				[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9'))
# 					[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9') is at /home/vignonl/tmp/climaf_cache/b4/1.nc:
# 					[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')
# 						[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg') is at /home/vignonl/tmp/climaf_cache/fc/7.nc:
# 					[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "selmon,7,8,9" "/home/vignonl/tmp/climaf_cache/af/b.nc" "tas" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "" "" "" /home/vignonl/tmp/climaf_cache/fc/7.nc
# 					[register   : cache.py  , L. 149 ] : INFO     : ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9') registered as /home/vignonl/tmp/climaf_cache/af/b.nc
# Done in 0.2 s with script computation for ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')
# 				[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/regrid.sh /home/vignonl/tmp/climaf_cache/b4/1.nc /home/vignonl/tmp/climaf_cache/af/b.nc /home/vignonl/tmp/climaf_cache/9b/e.nc
# 				[register   : cache.py  , L. 149 ] : INFO     : regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')) registered as /home/vignonl/tmp/climaf_cache/9b/e.nc
# Done in 0.1 s with script computation for regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9'))
# 				[ceval      : driver.py , L. 234 ] : INFO     : Object found in cache: ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9') is at /home/vignonl/tmp/climaf_cache/af/b.nc:
# 			[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:cdo sub /home/vignonl/tmp/climaf_cache/9b/e.nc /home/vignonl/tmp/climaf_cache/af/b.nc /home/vignonl/tmp/climaf_cache/ff/4.nc
# 			[register   : cache.py  , L. 149 ] : INFO     : minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')) registered as /home/vignonl/tmp/climaf_cache/ff/4.nc
# Done in 0.1 s with script computation for minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9'))
# 		[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:(ncl -Q /cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/gplot.ncl main_file='"/home/vignonl/tmp/climaf_cache/ff/4.nc"'     plotname='"/home/vignonl/tmp/climaf_cache/35/2.png"'     main_var='"tas"'    title='"Bias JAS"'                                    )
# 		[register   : cache.py  , L. 149 ] : INFO     : plot(minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),title='Bias JAS') registered as /home/vignonl/tmp/climaf_cache/35/2.png
# Done in 1.0 s with script computation for plot(minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),title='Bias JAS')
# 	[register   : cache.py  , L. 149 ] : INFO     : cpage([[plot(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),contours=1,title='JFM'),plot(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),contours=1,title='JAS')],[plot(minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,1,2,3'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,1,2,3')),title='Bias JFM'),plot(minus(regrid(ccdo(ccdo(ds('example.AMIPV6ALB2G.tas.1980-1981.global.monthly'),operator='ymonavg'),operator='selmon,7,8,9'),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),ccdo(ccdo(ds('cruts3.N/A.tas.1980-1981.global.T127'),operator='ymonavg'),operator='selmon,7,8,9')),title='Bias JAS')]],[0.5, 0.5],[0.2, 0.2], orientation='portrait', fig_trim='True', page_trim='True', format='png') registered as /home/vignonl/tmp/climaf_cache/41/3.png

# %% [markdown]
# # 11- Derived variables, the easy way

# %% [markdown]
# ### Define a dataset using a variable name that is not in data files - i.e. a 'derived' variable

# %%
creShortTop=ds(simulation="AMIPV6ALB2G",variable="crest")

# %% [markdown]
# ### Declare a new 'CliMAF operator', to be used for computing the derived variable

# %%
cscript('minus','cdo sub ${in_1} ${in_2} ${out}')
# Out:
# [__init__   : operators.py, L. 238 ] : WARNING  : Redefining CliMAF script minus
# CliMAF operator : minus

# %% [markdown]
# ### Tell how the derived variable is derived using operator 'minus' with inputs defined as similar datasets with alternate variables

# %%
derive('*', 'crest','minus','rst','rstcs')

# %% [markdown]
# ### You can use the 'derived' dataset in any expression; computation will occur when needed

# %%
my_ncview(creShortTop)
# Out:
# 	[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for my_ncview(ds('example.AMIPV6ALB2G.crest.1980-1981.global.monthly'))
# 			[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for minus(ds('example.AMIPV6ALB2G.rst.1980-1981.global.monthly'),ds('example.AMIPV6ALB2G.rstcs.1980-1981.global.monthly'))
# 					[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for select(ds('example.AMIPV6ALB2G.rst.1980-1981.global.monthly'))
# 					[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "" "/home/vignonl/tmp/climaf_cache/38/0.nc" "rst" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "" "" "" /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1980.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc
# 					[register   : cache.py  , L. 149 ] : INFO     : select(ds('example.AMIPV6ALB2G.rst.1980-1981.global.monthly')) registered as /home/vignonl/tmp/climaf_cache/38/0.nc
# Done in 0.4 s with script computation for select(ds('example.AMIPV6ALB2G.rst.1980-1981.global.monthly'))
# 					[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for select(ds('example.AMIPV6ALB2G.rstcs.1980-1981.global.monthly'))
# 					[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "" "/home/vignonl/tmp/climaf_cache/c3/9.nc" "rstcs" "1980-01-01T00:00:00,1981-12-31T23:59:00" "" "" "" "" /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1980.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc /cnrm/aster/data3/aster/vignonl/code/climaf/examples/data/AMIPV6ALB2G/A/AMIPV6ALB2GPL1981.nc
# 					[register   : cache.py  , L. 149 ] : INFO     : select(ds('example.AMIPV6ALB2G.rstcs.1980-1981.global.monthly')) registered as /home/vignonl/tmp/climaf_cache/c3/9.nc
# Done in 0.4 s with script computation for select(ds('example.AMIPV6ALB2G.rstcs.1980-1981.global.monthly'))
# 			[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:cdo sub /home/vignonl/tmp/climaf_cache/38/0.nc /home/vignonl/tmp/climaf_cache/c3/9.nc /home/vignonl/tmp/climaf_cache/11/b.nc
# 			[register   : cache.py  , L. 149 ] : INFO     : minus(ds('example.AMIPV6ALB2G.rst.1980-1981.global.monthly'),ds('example.AMIPV6ALB2G.rstcs.1980-1981.global.monthly')) registered as /home/vignonl/tmp/climaf_cache/11/b.nc
# Done in 0.1 s with script computation for minus(ds('example.AMIPV6ALB2G.rst.1980-1981.global.monthly'),ds('example.AMIPV6ALB2G.rstcs.1980-1981.global.monthly'))
# 	[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:ncview /home/vignonl/tmp/climaf_cache/11/b.nc
# my_ncview(ds('example.AMIPV6ALB2G.crest.1980-1981.global.monthly'))

# %% [markdown]
# # 12- CliMAF access to data organized according to CMIP5 DRS

# %% [markdown]
# ### This example will work as is on CNRM's Lustre and on IPSL's Ciclad, and can be easily tuned to other local CMIP5 datasets

# %% [markdown]
# ### First, let us declare a list of data for CNRM-CM CMIP5 data at theses sites (note : this is actually built-in , and not necessary)

# %%
urls_CMIP5_CNRM=["/cnrm/aster/data2/ESG/data1", "/cnrm/aster/data2/ESG/data2", "/cnrm/aster/data2/ESG/data5",
      "/cnrm/aster/data4/ESG/data6", "/cnrm/aster/data4/ESG/data7", "/cnrm/aster/data4/ESG/data8"]

urls_CMIP5_Ciclad=["/prodigfs/esg"]

# %% [markdown]
# ### Declare locations for searching data for all projects, experiment and frequencies, and that data located in dirs listed in urls_CMIP5_CNRM and urls_CMIP5_Ciclad is organized as 'CMIP5_DRS'

# %%
dataloc(project="CMIP5", organization="CMIP5_DRS", url=urls_CMIP5_CNRM+urls_CMIP5_Ciclad)
# Out:
# <climaf.dataloc.dataloc instance at 0x7f36dc039290>

# %% [markdown]
# ### Define a default value for some dataset facets

# %%
cdef("frequency","monthly") ;  cdef("project","CMIP5")

# %% [markdown]
# ### Define your dataset (a number of facets take default values)

# %%
tas1pc=ds(model="CNRM-CM5", experiment="1pctCO2", variable="tas", period="1860-1861")

# %% [markdown]
# ###  Display the basic filenames involved in the dataset (all filenames in one single string). CliMAF will search them at the data location which is the most specific among all declared data locations

# %%
files=tas1pc.baseFiles()
print files
# Out:
# /cnrm/aster/data2/ESG/data1/CMIP5/output1/CNRM-CERFACS/CNRM-CM5/1pctCO2/mon/atmos/Amon/r1i1p1/v20110701/tas/tas_Amon_CNRM-CM5_1pctCO2_r1i1p1_185001-189912.nc

# %% [markdown]
# ### Let CliMAF generate a file with the exact dataset in its disk cache (select period and/or variables, aggregate files...)

# %%
my_file=cfile(tas1pc)
print my_file
# Out:
# 		[ceval      : driver.py , L. 271 ] : INFO     : nothing relevant found in cache for select(ds('CMIP5.r1i1p1.tas.1860-1861.global.CNRM-CM5.1pctCO2.monthly.*.*.last'))
# 		[ceval_scri : driver.py , L. 505 ] : INFO     : Launching command:/cnrm/aster/data3/aster/vignonl/code/climaf/climaf/../scripts/mcdo.sh "" "/home/vignonl/tmp/climaf_cache/9e/2.nc" "tas" "1860-01-01T00:00:00,1861-12-31T23:59:00" "" "" "" "" /cnrm/aster/data2/ESG/data1/CMIP5/output1/CNRM-CERFACS/CNRM-CM5/1pctCO2/mon/atmos/Amon/r1i1p1/v20110701/tas/tas_Amon_CNRM-CM5_1pctCO2_r1i1p1_185001-189912.nc
# 		[register   : cache.py  , L. 149 ] : INFO     : select(ds('CMIP5.r1i1p1.tas.1860-1861.global.CNRM-CM5.1pctCO2.monthly.*.*.last')) registered as /home/vignonl/tmp/climaf_cache/9e/2.nc
# /home/vignonl/tmp/climaf_cache/9e/2.nc
# Done in 0.4 s with script computation for select(ds('CMIP5.r1i1p1.tas.1860-1861.global.CNRM-CM5.1pctCO2.monthly.*.*.last'))

# %% [markdown]
# # Much more at http://climaf.readthedocs.org.

# %% [markdown]
# ## Installing is easy.

# %% [markdown]
# ## You may use and/or contribute at various levels.
